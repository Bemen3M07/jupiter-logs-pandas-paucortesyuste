# %%
import logging

# Configurar el logger principal
logger = logging.getLogger("main_logger")
logger.setLevel(logging.DEBUG)

# Handler per a logs d'info
info_handler = logging.FileHandler("info.log")
info_handler.setLevel(logging.INFO)

# Handler per a logs d'error
error_handler = logging.FileHandler("error.log")
error_handler.setLevel(logging.ERROR)

# Formatador
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
info_handler.setFormatter(formatter)
error_handler.setFormatter(formatter)

# Afegir handlers al logger principal
logger.addHandler(info_handler)
logger.addHandler(error_handler)

# Exemple d'us
logger.info("info.")
logger.error("error.")

# Handler de pantalla
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_handler.setFormatter(formatter)

# Afegir al logger principal
logger.addHandler(console_handler)

# Exemple
logger.info("Aquest missatge també es mostra per pantalla.")
logger.error("Aquest error es mostra per pantalla i es guarda a error.log.")
# Out:
# 2024-11-20 18:38:10,142 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:10,142 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:10,142 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:10,145 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:10,145 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:10,145 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:13,147 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:13,147 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:13,147 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:13,149 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:13,149 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:13,149 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:16,151 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:16,151 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:16,151 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:16,153 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:16,153 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:16,153 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:19,156 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:19,156 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:19,156 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:19,158 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:19,158 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:19,158 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:22,160 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:22,160 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:22,160 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:22,162 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:22,162 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:22,162 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:25,164 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:25,164 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:25,164 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:25,166 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:25,166 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:25,166 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:28,169 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:28,169 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:28,169 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:28,171 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:28,171 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:28,171 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:31,173 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:31,173 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:31,173 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:31,175 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:31,175 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:31,175 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:34,176 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:34,176 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:34,176 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:34,179 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:34,179 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:34,179 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:37,181 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:37,181 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:37,181 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:37,182 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:37,182 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:37,182 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:40,184 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:40,184 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:40,184 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:40,186 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:40,186 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:40,186 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:43,188 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:43,188 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:43,188 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:43,190 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:43,190 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:43,190 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:46,192 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:46,192 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:46,192 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:46,194 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:46,194 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:46,194 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:49,196 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:49,196 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:49,196 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:49,198 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:49,198 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:49,198 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:52,200 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:52,200 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:52,200 - INFO - Aquest missatge també es mostra per pantalla.
# 2024-11-20 18:38:52,202 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:52,202 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# 2024-11-20 18:38:52,202 - ERROR - Aquest error es mostra per pantalla i es guarda a error.log.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 57
#      54 csv_logger.error("error csv")
#      56 # Pausa per evitar consum excessiu de recursos
# ---> 57 time.sleep(3)
#
# KeyboardInterrupt:
